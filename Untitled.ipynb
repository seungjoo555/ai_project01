# %%
import pandas as pd

# %%
sal_df = pd.DataFrame({
    "sal":[5000, 4500, 6000, 9000, 7000, 5500, 6200]
})

sal_df
# Out:
#     sal
# 0  5000
# 1  4500
# 2  6000
# 3  9000
# 4  7000
# 5  5500
# 6  6200

# %%
sal_df.describe()
# Out:
#                sal
# count     7.000000
# mean   6171.428571
# std    1490.765224
# min    4500.000000
# 25%    5250.000000
# 50%    6000.000000
# 75%    6600.000000
# max    9000.000000

# %%
sal_df.loc[7, "sal"] = 170000

# %%
sal_df.describe()
# Out:
#                  sal
# count       8.000000
# mean    26650.000000
# std     57938.588177
# min      4500.000000
# 25%      5375.000000
# 50%      6100.000000
# 75%      7500.000000
# max    170000.000000
