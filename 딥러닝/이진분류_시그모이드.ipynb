# %%
# math는 파이썬에서 수학적인 계산을 할 수 있도록 도와주는 라이브러리
# 여기서 자연상수 e를 가져옴. e는 약 2.71828... 값을 가지는 수학적으로 중요한 상수
from math import e

# %%
# 시그모이드 함수의 수식 :
# sigmoid(H(x)) = 1 / (1 + e^(-H(x)))
# 시그모이드 함수는 인공지능에서 입력값을 받아서 0과 1 사이의 값을 출력하는 함수
# 입력값을 확률(0~1사이의 값)로 바꿔주는 데 자주 사용됩니다.
# 예시 1: 선형 회귀 결과 (H(x))가 -5일 때 시그모이드 값을 계산합니다.
sigmoid_minus_5 = 1 / (1 + e**-(-5))
print(sigmoid_minus_5)

# 계산 결과는 약 0.0067 입니다.
# 선형 회귀 결과 (H(x))가 매우 작을 때(큰 음수일 때), 시그모이드 값은 거의 0에 가깝습니다.
# Out:
# 0.006692850924284857

# %%
# 예시 2: 선형 회귀 결과 (H(x))가 -2.5일 때 시그모이드 값을 계산합니다.
sigmoid_minus_2_5 = 1 / (1 + e**-(-2.5))
print(sigmoid_minus_2_5)

# 계산 결과는 약 0.0759 입니다.
# 선형 회귀 결과 (H(x))가 음수일 때, 시그모이드 값은 0과 0.5 사이의 값이 나옵니다.
# Out:
# 0.07585818002124356

# %%
# 예시 3: 선형 회귀 결과 (H(x))가 0일 때 시그모이드 값을 계산합니다.
sigmoid_0 = 1 / (1 + e**-(0))
print(sigmoid_0)

# 계산 결과는 정확히 0.5 입니다.
# 선형 회귀 결과 (H(x))가 0일 때 시그모이드 값은 항상 0.5입니다.
# Out:
# 0.5

# %%
# 예시 4: 선형 회귀 결과 (H(x))가 2.5일 때 시그모이드 값을 계산합니다.
sigmoid_2_5 = 1 / (1 + e**-(2.5))
print(sigmoid_2_5)

# 계산 결과는 약 0.9241 입니다.
# 선형 회귀 결과 (H(x))가 양수일 때, 시그모이드 값은 0.5와 1 사이의 값이 나옵니다.
# Out:
# 0.9241418199787566

# %%
# 예시 5: 선형 회귀 결과 (H(x))가 5일 때 시그모이드 값을 계산합니다.
sigmoid_5 = 1 / (1+ e**-(5))
print(sigmoid_5)

# 계산 결과는 약 0.9933 입니다.
# 선형 회귀 결과 (H(x))가 매우 클 때(큰 양수일 때), 시그모이드 값은 거의 1에 가깝습니다.
# Out:
# 0.9933071490757153

# %%
e
# Out:
# 2.718281828459045

# %%
e**-1
# Out:
# 0.36787944117144233

# %%
e**0
# Out:
# 1.0
